# %% [markdown]
# # ALUNOS:

# %% [markdown]
# # CIÊNCIA DE DADOS
# ## Desafio 2: Previsão da ocupação hospitalar
#
# ### Etapas:
# - Entendimento do problema
# - Tratamento dos Dados
# - Visualização dos dados
# - Análise Exploratória dos Dados
# - Aprendizado de máquina
#
# O **desafio** consiste na previsão de ocupação hospitalar, focando na análise dos dados de atendimentos do pronto atendimento.
#
# O **objetivo** é identificar os fatores que podem influenciar ou aumentar o número de entradas de pacientes nesse serviço. As causas para o aumento das entradas podem ser diversas e depender de diferentes variáveis. A partir da análise desses dados, o desafio é desenvolver modelos preditivos que ajudem a antecipar a demanda do pronto atendimento, permitindo uma melhor gestão da ocupação hospitalar e a alocação eficiente de recursos.
#
# Serão fornecidos os seguintes dados para a análise:
# - ID do atendimento
# - Data/hora da entrada
# - CID
# - Data de nascimento
# - Sexo
# - Clínica
# - Convenio
# - Classificação de Risco
# - Motivo da Alta
# - Data da Alta
# .

# %% [markdown]
# ## Importar as bibliotecas necessárias e a base de dados. Realizar a visualização da mesma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def corrigir_csv(caminho_arquivo):
    # os dados estão todos na primeira coluna apesar da presença dos cabeçalhos
    # é necessário separar os mesmos
    df = pd.read_csv(caminho_arquivo, sep=";", dtype=str)

    if df.shape[1] == 1:
        df = df.iloc[:, 0].str.split(";", expand=True)
        df.columns = df.iloc[0]
        df = df[1:].reset_index(drop=True)
    
    return df

atendimentos = corrigir_csv("csv/Atendimentos Hospital.csv")
risco = corrigir_csv("csv/Classificação Risco.csv")
diagnosticos = corrigir_csv("csv/Diagnósticos.csv")
glasgow = corrigir_csv("csv/Escala Glasglow.csv")
internamentos = corrigir_csv("csv/Internamentos.csv")
procedimentos = corrigir_csv("csv/Procedimentos Realizados.csv")
sinais = corrigir_csv("csv/Sinais Vitais.csv")

dados = [ atendimentos, risco, diagnosticos, glasgow, internamentos, procedimentos, sinais ]

# %%
for dado in dados:
    print(dado.head(5))
    print('--- // ---')
# Out:
#   id_atendimento id_paciente           dt_atendimento ds_especialidade  \
# 0        1770909      441245  2022-06-04 14:40:08.000        Pediatria
# 1        1770967      148092  2022-06-04 17:48:54.000           Médico
# 2        1771006      186203  2022-06-04 20:43:46.000        Pediatria
# 3        1773849      639654  2022-06-08 12:36:11.000        Pediatria
# 4        1776305      582637  2022-06-11 14:47:17.000        Pediatria
#
#              dt_nascimento    ds_sexo ds_tipo_atendimento ds_motivo_alta  \
# 0  2015-02-04 00:00:00.000  Masculino      Pronto Socorro           Alta
# 1  1940-07-18 00:00:00.000   Feminino      Pronto Socorro           Alta
# 2  2009-05-28 00:00:00.000  Masculino      Pronto Socorro           Alta
# 3  2018-12-05 00:00:00.000  Masculino      Pronto Socorro           Alta
# 4  2019-04-03 00:00:00.000   Feminino      Pronto Socorro           Alta
#
#   ds_convenio  ds_clinica                  dt_alta
# 0      Unimed  Pediátrica  2022-06-04 16:26:03.000
# 1      Unimed      Médica  2022-06-04 18:39:31.000
# 2      Unimed  Pediátrica  2022-06-05 08:43:46.000
# 3      Unimed  Pediátrica  2022-06-08 13:28:21.000
# 4      Unimed  Pediátrica  2022-06-11 15:43:27.000
# --- // ---
#   id_atendimento               dt_triagem  \
# 0        2112883  2023-09-01 00:00:00.000
# 1        2178973  2023-10-01 00:00:00.000
# 2        2198796  2023-11-01 00:00:00.000
# 3        2146615  2023-09-01 00:00:00.000
# 4        2193941  2023-10-01 00:00:00.000
#
#                                           ds_risco
# 0  Não Urgente - Sem Risco/Prioridade Legal (Azul)
# 1  Não Urgente - Sem Risco/Prioridade Legal (Azul)
# 2  Não Urgente - Sem Risco/Prioridade Legal (Azul)
# 3  Não Urgente - Sem Risco/Prioridade Legal (Azul)
# 4  Não Urgente - Sem Risco/Prioridade Legal (Azul)
# --- // ---
#   id_atendimento id_paciente id_medico           dt_diagnostico cd_doenca  \
# 0        1767770      515787    170556  2022-06-01 03:30:57.000      B349
# 1        1767598      218784    508784  2022-06-01 04:03:54.000      M070
# 2        1767774      631697    170556  2022-06-01 04:08:04.000      B349
# 3        1767835      636221       555  2022-06-01 07:57:51.000      T784
# 4        1767893      206278    224305  2022-06-01 08:01:44.000      J069
#
#   ds_tipo_diagnostico
# 0           Principal
# 1           Principal
# 2           Principal
# 3           Principal
# 4           Principal
# --- // ---
#   id_atendimento id_pessoa_fisica             dt_avaliacao qt_glasgow
# 0         875878           821581  2018-01-30 13:40:14.000         15
# 1         875878           794862  2019-01-07 17:12:26.000          3
# 2         875878           794862  2019-01-07 14:14:52.000          3
# 3         875878           794862  2019-01-07 20:12:37.000          3
# 4         875878           794862  2019-02-11 07:58:51.000          3
# --- // ---
#   id_atendimento id_paciente           dt_atendimento  \
# 0         476558      138848  2014-04-08 04:54:23.000
# 1         458377      224823  2014-01-27 09:55:52.000
# 2         460581      376064  2014-02-04 18:30:40.000
# 3         456899      132888  2014-01-20 22:57:06.000
# 4         402150      206255  2013-06-24 15:16:44.000
#
#             ds_especialidade            dt_nascimento    ds_sexo  \
# 0       Otorrinolaringologia  1976-05-01 00:00:00.000   Feminino
# 1        Cirurgia Pediátrica  2002-10-31 00:00:00.000  Masculino
# 2          Cirurgia Torácica  1965-10-07 00:00:00.000  Masculino
# 3             Cirurgia Geral  1979-11-20 00:00:00.000  Masculino
# 4  Hematologia e Hemoterapia  1923-11-17 00:00:00.000  Masculino
#
#   ds_tipo_atendimento  ds_motivo_alta ds_convenio ds_clinica  \
# 0           Internado  Alta melhorado      Unimed  Cirurgica
# 1           Internado  Alta melhorado      Unimed  Cirurgica
# 2           Internado  Alta melhorado      Unimed     Médica
# 3           Internado  Alta melhorado      Unimed     Médica
# 4           Internado  Alta melhorado      Unimed     Médica
#
#                    dt_alta
# 0  2014-04-08 16:04:03.000
# 1  2014-01-27 17:18:05.000
# 2  2014-02-07 20:57:03.000
# 3  2014-01-23 11:47:37.000
# 4  2013-07-02 10:57:36.000
# --- // ---
#   id_atendimento id_paciente id_medico cd_procedimento  \
# 0        2009683      841721    794198        20203047
# 1        2088858      620969    621366        40804054
# 2        2420094      648016    350126        40801012
# 3        2078529      414401    794384        31206220
# 4        1952125      119981    305830        31206220
#
#            dt_procedimento qt_procedimento     ds_especialidade
# 0  2023-05-17 10:29:52.000               1          Cardiologia
# 1  2023-08-20 18:27:00.000               1        Clínica Geral
# 2  2024-05-20 21:30:00.000               1        Clínica Geral
# 3  2023-08-10 14:05:00.000               1  Cirurgia Pediátrica
# 4  2023-02-23 15:50:00.000               1             Urologia
# --- // ---
#   id_atendimento id_paciente           dt_sinal_vital qt_pa_sistolica  \
# 0         875878      951627  2018-01-30 07:11:14.000             120
# 1         875878      951627  2018-01-30 07:13:03.000             120
# 2         875878      951627  2018-01-30 07:14:59.000             120
# 3         875878      951627  2018-01-30 07:16:50.000             120
# 4         875878      951627  2018-01-30 07:25:25.000             120
#
#   qt_pa_diastolica qt_freq_cardiaca qt_temp qt_peso qt_imc qt_altura_cm
# 0               80               80      37     NaN    NaN          NaN
# 1               80               80      37     NaN    NaN          NaN
# 2               80               70      37     NaN    NaN          NaN
# 3               80               70      37     NaN    NaN          NaN
# 4               80               70      37     NaN    NaN          NaN
# --- // ---

# %% [markdown]
# ## Tratamento dos dados: verificar e corrigir o domínios dos campos, se há dados faltantes, verificar cardinalidade, identificar colunas categóricas, de visualizar as informações estatísticas da base (dados numéricos e não numéricos)

# %%
for dado in dados:
    dado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222122 entries, 0 to 222121
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_atendimento       222122 non-null  object
#  1   id_paciente          222122 non-null  object
#  2   dt_atendimento       222122 non-null  object
#  3   ds_especialidade     221981 non-null  object
#  4   dt_nascimento        222001 non-null  object
#  5   ds_sexo              222122 non-null  object
#  6   ds_tipo_atendimento  222122 non-null  object
#  7   ds_motivo_alta       221798 non-null  object
#  8   ds_convenio          222122 non-null  object
#  9   ds_clinica           221973 non-null  object
#  10  dt_alta              221798 non-null  object
# dtypes: object(11)
# memory usage: 18.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384379 entries, 0 to 384378
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_atendimento  384379 non-null  object
#  1   dt_triagem      384379 non-null  object
#  2   ds_risco        384379 non-null  object
# dtypes: object(3)
# memory usage: 8.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222800 entries, 0 to 222799
# Data columns (total 6 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_atendimento       222800 non-null  object
#  1   id_paciente          222800 non-null  object
#  2   id_medico            222800 non-null  object
#  3   dt_diagnostico       222800 non-null  object
#  4   cd_doenca            222800 non-null  object
#  5   ds_tipo_diagnostico  222800 non-null  object
# dtypes: object(6)
# memory usage: 10.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253702 entries, 0 to 253701
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_atendimento    253702 non-null  object
#  1   id_pessoa_fisica  253702 non-null  object
#  2   dt_avaliacao      253702 non-null  object
#  3   qt_glasgow        253702 non-null  object
# dtypes: object(4)
# memory usage: 7.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163605 entries, 0 to 163604
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_atendimento       163605 non-null  object
#  1   id_paciente          163605 non-null  object
#  2   dt_atendimento       163605 non-null  object
#  3   ds_especialidade     158411 non-null  object
#  4   dt_nascimento        163164 non-null  object
#  5   ds_sexo              163605 non-null  object
#  6   ds_tipo_atendimento  163605 non-null  object
#  7   ds_motivo_alta       163198 non-null  object
#  8   ds_convenio          163605 non-null  object
#  9   ds_clinica           163357 non-null  object
#  10  dt_alta              163201 non-null  object
# dtypes: object(11)
# memory usage: 13.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251290 entries, 0 to 251289
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_atendimento    251290 non-null  object
#  1   id_paciente       251290 non-null  object
#  2   id_medico         251290 non-null  object
#  3   cd_procedimento   251290 non-null  object
#  4   dt_procedimento   251290 non-null  object
#  5   qt_procedimento   251290 non-null  object
#  6   ds_especialidade  251271 non-null  object
# dtypes: object(7)
# memory usage: 13.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792829 entries, 0 to 792828
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_atendimento    792829 non-null  object
#  1   id_paciente       792829 non-null  object
#  2   dt_sinal_vital    792829 non-null  object
#  3   qt_pa_sistolica   552394 non-null  object
#  4   qt_pa_diastolica  552248 non-null  object
#  5   qt_freq_cardiaca  623113 non-null  object
#  6   qt_temp           459751 non-null  object
#  7   qt_peso           264144 non-null  object
#  8   qt_imc            215546 non-null  object
#  9   qt_altura_cm      320172 non-null  object
# dtypes: object(10)
# memory usage: 60.5+ MB

# %%
# atendimentos
atendimentos['dt_atendimento'] = pd.to_datetime(atendimentos['dt_atendimento'], errors='coerce')
atendimentos['dt_nascimento'] = pd.to_datetime(atendimentos['dt_nascimento'], errors='coerce')
atendimentos['dt_alta'] = pd.to_datetime(atendimentos['dt_alta'], errors='coerce')

# classificação de risco
risco['dt_triagem'] = pd.to_datetime(risco['dt_triagem'], errors='coerce')

# diagnósticos
diagnosticos['dt_diagnostico'] = pd.to_datetime(diagnosticos['dt_diagnostico'], errors='coerce')

# glasgow
glasgow['dt_avaliacao'] = pd.to_datetime(glasgow['dt_avaliacao'], errors='coerce')
glasgow['qt_glasgow'] = pd.to_numeric(glasgow['qt_glasgow'], errors='coerce')

# internamentos
internamentos['dt_atendimento'] = pd.to_datetime(internamentos['dt_atendimento'], errors='coerce')
internamentos['dt_nascimento'] = pd.to_datetime(internamentos['dt_nascimento'], errors='coerce')
internamentos['dt_alta'] = pd.to_datetime(internamentos['dt_alta'], errors='coerce')

# procedimentos realizados

# sinais vitais
sinais['dt_sinal_vital'] = pd.to_datetime(sinais['dt_sinal_vital'], errors='coerce')

# %%
for dado in dados:
    dado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222122 entries, 0 to 222121
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_atendimento       222122 non-null  object
#  1   id_paciente          222122 non-null  object
#  2   dt_atendimento       222122 non-null  datetime64[ns]
#  3   ds_especialidade     221981 non-null  object
#  4   dt_nascimento        222001 non-null  datetime64[ns]
#  5   ds_sexo              222122 non-null  object
#  6   ds_tipo_atendimento  222122 non-null  object
#  7   ds_motivo_alta       221798 non-null  object
#  8   ds_convenio          222122 non-null  object
#  9   ds_clinica           221973 non-null  object
#  10  dt_alta              221798 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), object(8)
# memory usage: 18.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384379 entries, 0 to 384378
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_atendimento  384379 non-null  object
#  1   dt_triagem      384379 non-null  datetime64[ns]
#  2   ds_risco        384379 non-null  object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 8.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222800 entries, 0 to 222799
# Data columns (total 6 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_atendimento       222800 non-null  object
#  1   id_paciente          222800 non-null  object
#  2   id_medico            222800 non-null  object
#  3   dt_diagnostico       222800 non-null  datetime64[ns]
#  4   cd_doenca            222800 non-null  object
#  5   ds_tipo_diagnostico  222800 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 10.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253702 entries, 0 to 253701
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_atendimento    253702 non-null  object
#  1   id_pessoa_fisica  253702 non-null  object
#  2   dt_avaliacao      253701 non-null  datetime64[ns]
#  3   qt_glasgow        253702 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 7.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163605 entries, 0 to 163604
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_atendimento       163605 non-null  object
#  1   id_paciente          163605 non-null  object
#  2   dt_atendimento       163605 non-null  datetime64[ns]
#  3   ds_especialidade     158411 non-null  object
#  4   dt_nascimento        163164 non-null  datetime64[ns]
#  5   ds_sexo              163605 non-null  object
#  6   ds_tipo_atendimento  163605 non-null  object
#  7   ds_motivo_alta       163198 non-null  object
#  8   ds_convenio          163605 non-null  object
#  9   ds_clinica           163357 non-null  object
#  10  dt_alta              163201 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), object(8)
# memory usage: 13.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251290 entries, 0 to 251289
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_atendimento    251290 non-null  object
#  1   id_paciente       251290 non-null  object
#  2   id_medico         251290 non-null  object
#  3   cd_procedimento   251290 non-null  object
#  4   dt_procedimento   251290 non-null  object
#  5   qt_procedimento   251290 non-null  object
#  6   ds_especialidade  251271 non-null  object
# dtypes: object(7)
# memory usage: 13.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792829 entries, 0 to 792828
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_atendimento    792829 non-null  object
#  1   id_paciente       792829 non-null  object
#  2   dt_sinal_vital    792829 non-null  datetime64[ns]
#  3   qt_pa_sistolica   552394 non-null  object
#  4   qt_pa_diastolica  552248 non-null  object
#  5   qt_freq_cardiaca  623113 non-null  object
#  6   qt_temp           459751 non-null  object
#  7   qt_peso           264144 non-null  object
#  8   qt_imc            215546 non-null  object
#  9   qt_altura_cm      320172 non-null  object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 60.5+ MB

# %%
# cardinalidade
for dado in dados:
    print(dado.nunique())
# Out:
# id_atendimento         222122
# id_paciente             80809
# dt_atendimento         219942
# ds_especialidade           57
# dt_nascimento           25192
# ds_sexo                     2
# ds_tipo_atendimento         5
# ds_motivo_alta             11
# ds_convenio                 8
# ds_clinica                 33
# dt_alta                219409
# dtype: int64
# id_atendimento    204645
# dt_triagem            25
# ds_risco               6
# dtype: int64
# id_atendimento         214272
# id_paciente             79303
# id_medico                 560
# dt_diagnostico         220728
# cd_doenca                3013
# ds_tipo_diagnostico         2
# dtype: int64
# id_atendimento      148470
# id_pessoa_fisica       336
# dt_avaliacao        226859
# qt_glasgow              16
# dtype: int64
# id_atendimento         163605
# id_paciente             95525
# dt_atendimento         159756
# ds_especialidade           53
# dt_nascimento           28825
# ds_sexo                     2
# ds_tipo_atendimento         1
# ds_motivo_alta             22
# ds_convenio                12
# ds_clinica                 37
# dt_alta                156628
# dtype: int64
# id_atendimento      194593
# id_paciente          76305
# id_medico              388
# cd_procedimento        690
# dt_procedimento     234654
# qt_procedimento         18
# ds_especialidade        44
# dtype: int64
# id_atendimento      224707
# id_paciente          86897
# dt_sinal_vital      698495
# qt_pa_sistolica        270
# qt_pa_diastolica       201
# qt_freq_cardiaca       399
# qt_temp                168
# qt_peso               3354
# qt_imc                2143
# qt_altura_cm           486
# dtype: int64

# %%
# nulos
for dado in dados:
    print(dado.isnull().sum())
# Out:
# id_atendimento           0
# id_paciente              0
# dt_atendimento           0
# ds_especialidade       141
# dt_nascimento          121
# ds_sexo                  0
# ds_tipo_atendimento      0
# ds_motivo_alta         324
# ds_convenio              0
# ds_clinica             149
# dt_alta                324
# idade                  121
# dtype: int64
# id_atendimento    0
# dt_triagem        0
# ds_risco          0
# dtype: int64
# id_atendimento         0
# id_paciente            0
# id_medico              0
# dt_diagnostico         0
# cd_doenca              0
# ds_tipo_diagnostico    0
# dtype: int64
# id_atendimento      0
# id_pessoa_fisica    0
# dt_avaliacao        1
# qt_glasgow          0
# dtype: int64
# id_atendimento            0
# id_paciente               0
# dt_atendimento            0
# ds_especialidade       5194
# dt_nascimento           441
# ds_sexo                   0
# ds_tipo_atendimento       0
# ds_motivo_alta          407
# ds_convenio               0
# ds_clinica              248
# dt_alta                 404
# dtype: int64
# id_atendimento       0
# id_paciente          0
# id_medico            0
# cd_procedimento      0
# dt_procedimento      0
# qt_procedimento      0
# ds_especialidade    19
# dtype: int64
# id_atendimento           0
# id_paciente              0
# dt_sinal_vital           0
# qt_pa_sistolica     240435
# qt_pa_diastolica    240581
# qt_freq_cardiaca    169716
# qt_temp             333078
# qt_peso             528685
# qt_imc              577283
# qt_altura_cm        472657
# dtype: int64

# %%
# dados estatísticos
for dado in dados:
    print(dado.describe())
# Out:
#                       dt_atendimento                  dt_nascimento  \
# count                         222122                         222001
# mean   2023-07-04 21:46:39.442698496  1995-01-05 15:38:38.535502208
# min              2022-06-01 00:02:48            1916-08-19 00:00:00
# 25%    2022-12-21 23:02:24.249999872            1982-11-18 00:00:00
# 50%              2023-07-07 17:20:27            1996-01-28 00:00:00
# 75%    2024-02-06 20:53:05.249999872            2013-09-30 00:00:00
# max              2024-05-31 23:46:36            2024-05-27 00:00:00
# std                              NaN                            NaN
#
#                              dt_alta          idade
# count                         221798  222001.000000
# mean   2023-07-05 01:09:14.675844352      28.013013
# min              2021-04-19 17:04:23       0.000000
# 25%       2022-12-22 01:23:44.500000       9.000000
# 50%              2023-07-07 17:29:57      27.000000
# 75%    2024-02-07 10:01:54.750000128      40.000000
# max              2024-12-02 13:00:00     106.000000
# std                              NaN      20.496459
#                           dt_triagem
# count                         384379
# mean   2023-07-02 17:53:35.573171200
# min              2022-06-01 00:00:00
# 25%              2023-01-01 00:00:00
# 50%              2023-07-01 00:00:00
# 75%              2024-02-01 00:00:00
# max              2024-06-01 00:00:00
#                       dt_diagnostico
# count                         222800
# mean   2023-07-07 21:33:46.939959552
# min              2022-06-01 00:01:37
# 25%              2022-12-24 00:30:15
# 50%       2023-07-12 11:21:36.500000
# 75%    2024-02-11 20:30:53.249999872
# max              2024-05-31 23:52:22
#                         dt_avaliacao
# count                         253701
# mean   2023-07-05 15:17:31.524561664
# min              2018-01-30 13:40:14
# 25%              2023-01-12 20:57:36
# 50%              2023-07-04 15:12:45
# 75%              2024-01-02 10:57:15
# max              2222-08-18 10:00:00
#                       dt_atendimento                  dt_nascimento  \
# count                         163605                         163164
# mean   2018-11-19 08:03:11.455982592  1982-05-15 04:58:24.265107456
# min              2001-10-16 18:02:31            1906-07-02 00:00:00
# 25%              2015-12-14 19:10:13            1970-03-08 00:00:00
# 50%              2020-03-24 13:31:53            1983-12-23 00:00:00
# 75%              2021-09-22 15:29:12            1995-02-23 00:00:00
# max              2024-12-26 15:11:51            2024-12-26 00:00:00
#
#                              dt_alta
# count                         163201
# mean   2019-01-01 19:53:54.655418880
# min              2009-04-20 11:15:21
# 25%              2015-12-13 12:08:23
# 50%              2020-03-23 13:43:12
# 75%              2022-03-17 13:11:22
# max              2024-12-26 15:17:13
#        id_atendimento id_paciente id_medico cd_procedimento  \
# count          251290      251290    251290          251290
# unique         194593       76305       388             690
# top           1963059      614215    224305        10101039
# freq              126         178     17084          183282
#
#                 dt_procedimento qt_procedimento ds_especialidade
# count                    251290          251290           251271
# unique                   234654              18               44
# top     2023-06-14 19:19:00.000               1        Pediatria
# freq                         16          249811            67076
#                       dt_sinal_vital
# count                         792829
# mean   2023-06-26 06:33:09.116788480
# min              2018-01-30 07:11:14
# 25%              2022-12-28 09:05:43
# 50%              2023-07-02 11:33:01
# 75%              2023-12-28 17:25:45
# max              2024-12-18 09:11:16

# %%
# as colunas com baixa cardinalidade são:
# sexo
# especialidade
# tipo_atendimento
# motivo_alta
# convenio
# clinica
# risco
# tipo_diagnostico
# glasgow

# %%
# colunas determinadas como categóricas
# atendimentos: sexo, motivo_alta, ds_convenio, ds_clinica, ds_especialidade
# risco: ds_risco
# diagnosticos: ds_tipo_diagnostico,

# %% [markdown]
# ## Visualizando de forma gráfica: utilizar as boas práticas de visualização de dados

# %%
# distribuição de atendimentos por especialidade (quais especialidades tem maior demanda)
especialidades = atendimentos['ds_especialidade'].value_counts()
plt.figure(figsize=(15, 5))
especialidades.plot(kind='bar', color='blue')
plt.title('Distribuição de Pacientes por Especialidade')
plt.xlabel('Especialidade')
plt.ylabel('Número de Atendimentos')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# evolucao da ocupação ao longo do tempo (picos e sazonalidades)
atendimentos_por_dia = atendimentos['dt_atendimento'].value_counts().sort_index()
plt.figure(figsize=(12, 5))
atendimentos_por_dia.plot(kind='line', color='red')
plt.title('Frequência de Atendimentos Hospitalares')
plt.xlabel('Data')
plt.ylabel('Número de Atendimentos')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
# classificação de risco
classificacao_risco = risco['ds_risco'].value_counts()
plt.figure(figsize=(8, 4))
classificacao_risco.plot(kind='bar', color='orange')
plt.title('Distribuição dos Atendimentos por Nível de Risco')
plt.xlabel('Classificação de Risco')
plt.ylabel('Número de Pacientes')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# distribuição demográfica
atendimentos['idade'] = (atendimentos['dt_atendimento'] - atendimentos['dt_nascimento']).dt.days // 365
plt.figure(figsize=(10, 5))
atendimentos['idade'].plot(kind='hist', bins=30, color='purple', edgecolor='black')
plt.title('Distribuição de Idades dos Pacientes')
plt.xlabel('Idade')
plt.ylabel('Número de Pacientes')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Análise Exploratória dos dados
#
# **O boxplot**
#
# - Permite visualizar os percentis e valores máximo e mínimo dos dados
# - Permite visualizar, além de simetria e dispersão dos dados, valores extremos (outliers)
# - O valor máximo e mínimo são calculados baseado no interquartil

# %%
atendimentos['idade'].plot(kind='box', figsize=(10,6), subplots=True)
# Out:
# idade    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
glasgow['qt_glasgow'].plot(kind='box', figsize=(10,6), subplots=True)
# Out:
# qt_glasgow    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# **Criando uma matriz para mostrar a correlação de cada par de variáveis**

# %%
# Apresentar a matriz de correlação da base
from pandas.plotting import scatter_matrix
# isolando colunas relevantes
colunas_numericas = atendimentos['Open', 'High', 'Low', 'Close', 'Volume']

plt.figure(figsize=(10, 8))
scatter_matrix(df[colunas_numericas], figsize=(10, 8))
plt.show()

# %%
# Apresentar a matriz de correlação da base plotando no pairplot

# %% [markdown]
# ## Visualizando apenas o KDE**
# - KDE: Kernel Density Estimation
#     - Mede a chance de uma variável aleatória assumir determinado valor
#     - A probabilidade é dada pela integral abaixo da curva na faixa de valor selecionada
# - Parece uma "versão de linha suavizada" de um histograma

# %% [markdown]
# ## Heatmap de correlação

# %% [markdown]
# ## Aprendizado de Máquina
#
# - Definir 3 algorítmos de aprendizado de máquina a ser testado no Desafio

# %%
# Importar as bibliotecas necessárias
# Definir as variáveis de input e a target
# Dividir a base de dados em treino e teste

# %%
# Treinar o modelo
# Predizer o modelo
# Avaliar o modelo

# %% [markdown]
# ## Apresente uma conclusão para o desafio, demonstrando graficamente
